# %% [markdown]
# ### IMPORTS

# %%
# general
from pprint import pprint
from pathlib import Path
import random
from IPython.display import Image, display

# main
from parseimagenet import get_image_paths_by_keywords
from parseimagenet import get_available_presets, KEYWORD_PRESETS

# check
# !pip show parseimagenet

# %% [markdown]
# ### Explore

# %%
# See list of available preset names
print(get_available_presets())  # ['birds']
# Out:
# ['birds']

# %%
# Inspect the actual keywords in a preset
print(KEYWORD_PRESETS["birds"])  # ['bird', 'sparrow', 'eagle', ...]())
# Out:
# ['bird', 'finch', 'robin', 'eagle', 'hawk', 'owl', 'sparrow', 'warbler', 'hummingbird', 'jay', 'cardinal', 'chickadee', 'duck', 'goose', 'swan', 'crane', 'heron', 'pelican', 'parrot', 'cockatoo', 'macaw', 'penguin', 'ostrich', 'brambling', 'bunting', 'junco', 'oriole', 'magpie', 'cock', 'hen', 'rooster', 'chicken', 'grouse', 'partridge', 'quail', 'pheasant', 'peacock', 'flamingo', 'stork', 'albatross', 'cormorant', 'kingfisher', 'hornbill', 'toucan', 'woodpecker', 'flycatcher', 'shrike', 'vireo', 'wren', 'thrush', 'mockingbird', 'starling', 'pipit']

# %% [markdown]
# # USE

# %%
# Set the path to your ImageNet directory
base_path = Path('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset')

# Get image paths matching keywords from the `LOC_synset_mapping.txt` file
image_paths = get_image_paths_by_keywords(
    base_path=base_path,
    preset="birds",
    num_images=100
)
pprint(image_paths[:10])
# Out:
# Loading category names...
# Loaded 1000 categories
#
# Parsing training annotations...
# Found 1000 unique categories
#
# ================================================================================
# SEARCHING WITH KEYWORDS: ['bird', 'finch', 'robin', 'eagle', 'hawk', 'owl', 'sparrow', 'warbler', 'hummingbird', 'jay', 'cardinal', 'chickadee', 'duck', 'goose', 'swan', 'crane', 'heron', 'pelican', 'parrot', 'cockatoo', 'macaw', 'penguin', 'ostrich', 'brambling', 'bunting', 'junco', 'oriole', 'magpie', 'cock', 'hen', 'rooster', 'chicken', 'grouse', 'partridge', 'quail', 'pheasant', 'peacock', 'flamingo', 'stork', 'albatross', 'cormorant', 'kingfisher', 'hornbill', 'toucan', 'woodpecker', 'flycatcher', 'shrike', 'vireo', 'wren', 'thrush', 'mockingbird', 'starling', 'pipit']
# ================================================================================
# n01514668: cock (1300 images)
# n01514859: hen (1300 images)
# n01518878: ostrich, Struthio camelus (1300 images)
# n01530575: brambling, Fringilla montifringilla (1300 images)
# n01531178: goldfinch, Carduelis carduelis (1300 images)
# n01532829: house finch, linnet, Carpodacus mexicanus (1300 images)
# n01534433: junco, snowbird (1300 images)
# n01537544: indigo bunting, indigo finch, indigo bird, Passerina cyanea (1300 images)
# n01558993: robin, American robin, Turdus migratorius (1300 images)
# n01580077: jay (1300 images)
# n01582220: magpie (1300 images)
# n01592084: chickadee (1300 images)
# n01614925: bald eagle, American eagle, Haliaeetus leucocephalus (1300 images)
# n01622779: great grey owl, great gray owl, Strix nebulosa (1300 images)
# n01795545: black grouse (1300 images)
# n01797886: ruffed grouse, partridge, Bonasa umbellus (1300 images)
# n01798484: prairie chicken, prairie grouse, prairie fowl (1300 images)
# n01806143: peacock (1300 images)
# n01806567: quail (1300 images)
# n01807496: partridge (1300 images)
# n01818515: macaw (1300 images)
# n01819313: sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita (1300 images)
# n01829413: hornbill (1300 images)
# n01833805: hummingbird (1300 images)
# n01843383: toucan (1300 images)
# n01855672: goose (1300 images)
# n01860187: black swan, Cygnus atratus (1300 images)
# n01873310: platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus (1272 images)
# n02002556: white stork, Ciconia ciconia (1300 images)
# n02002724: black stork, Ciconia nigra (1300 images)
# n02007558: flamingo (1300 images)
# n02009229: little blue heron, Egretta caerulea (1300 images)
# n02009912: American egret, great white heron, Egretta albus (1300 images)
# n02012849: crane (1300 images)
# n02018207: American coot, marsh hen, mud hen, water hen, Fulica americana (1300 images)
# n02051845: pelican (1300 images)
# n02056570: king penguin, Aptenodytes patagonica (1300 images)
# n02058221: albatross, mollymawk (1300 images)
# n02088364: beagle (1300 images)
# n02102318: cocker spaniel, English cocker spaniel, cocker (1300 images)
# n02137549: mongoose (1300 images)
# n02165456: ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle (1300 images)
# n02233338: cockroach, roach (1300 images)
# n02268443: dragonfly, darning needle, devil's darning needle, sewing needle, snake feeder, snake doctor, mosquito hawk, skeeter hawk (1300 images)
# n02492660: howler monkey, howler (1300 images)
# n02843684: birdhouse (1300 images)
# n03062245: cocktail shaker (1154 images)
# n03126707: crane (1300 images)
# n03775546: mixing bowl (1300 images)
# n04263257: soup bowl (1300 images)
# n04553703: washbasin, handbasin, washbowl, lavabo, wash-hand basin (1300 images)
# n13052670: hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa (1300 images)
#
# ================================================================================
# Total matching categories: 52
# ================================================================================
#
# Total matching images available: 67426
#
# Selected 100 random images
# Verified 100/100 files exist on disk
#
# [PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02102318/n02102318_9574.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02058221/n02058221_4184.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02012849/n02012849_6148.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n01833805/n01833805_585.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n01530575/n01530575_7443.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n01514859/n01514859_19674.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n01818515/n01818515_5234.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n01558993/n01558993_13061.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02056570/n02056570_3365.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02009912/n02009912_10172.JPEG')]

# %%
random_index = random.randrange(len(image_paths))
display(Image(filename=image_paths[random_index]))
