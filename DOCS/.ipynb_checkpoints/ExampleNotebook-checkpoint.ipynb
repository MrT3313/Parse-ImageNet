# %% [markdown]
# # IMPORTS

# %%
# general
from pprint import pprint
from pathlib import Path
import random
from IPython.display import Image, display

# main
from parseimagenet import get_image_paths_by_keywords
from parseimagenet import get_available_presets, KEYWORD_PRESETS

# check
# !pip show parseimagenet
# Out:
# Name: parseimagenet
# Version: 1.5.0
# Summary: Extract ImageNet image paths by category keywords
# Home-page: https://github.com/MrT3313/Parse-ImageNet
# Author:
# Author-email: Reed Turgeon <turgeon.dev@gmail.com>
# License: MIT
# Location: /opt/homebrew/Caskroom/miniconda/base/envs/FastAI/lib/python3.12/site-packages
# Editable project location: /Users/mrt/Documents/MrT/code/computer-vision/ParseImageNet
# Requires:
# Required-by:

# %% [markdown]
# # USE

# %%
# Set the path to your ImageNet directory
base_path = Path('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset')

# %% [markdown]
# ## Explore

# %%
# See list of available preset names
print(get_available_presets())
# Out:
# ['birds', 'dogs', 'wild_canids', 'snakes']

# %%
# Inspect the actual keywords in a preset (first 10)
print(f'Bird Keywords:\n{KEYWORD_PRESETS["birds"][:10]}\n')
print(f'Snake Keywords:\n{KEYWORD_PRESETS["snakes"][:10]}\n')
print(f'Dog Keywords:\n{KEYWORD_PRESETS["dogs"][:10]}\n')
print(f'Wild Canid Keywords:\n{KEYWORD_PRESETS["wild_canids"][:10]}\n')
# Out:
# Bird Keywords:
# ['albatross', 'American coot', 'American eagle', 'American egret', 'American robin', 'Aptenodytes patagonica', 'Aramus pictus', 'Arenaria interpres', 'bald eagle', 'bee eater']
#
# Snake Keywords:
# ['boa constrictor', 'Carphophis amoenus', 'Cerastes cornutus', 'Crotalus adamanteus', 'Crotalus cerastes', 'diamondback rattlesnake', 'garter snake', 'grass snake', 'green mamba', 'green snake']
#
# Dog Keywords:
# ['affenpinscher', 'Afghan hound', 'Airedale', 'Airedale terrier', 'Alaskan malamute', 'alsatian', 'American pit bull terrier', 'American Staffordshire terrier', 'Australian terrier', 'basset']
#
# Wild Canid Keywords:
# ['African hunting dog', 'Canis dingo', 'Cape hunting dog', 'Cuon alpinus', 'dhole', 'dingo', 'hyena dog', 'Lycaon pictus', 'warragal', 'warrigal']

# %% [markdown]
# ## Fetch Random Train Images

# %%
train_random_image_paths = get_image_paths_by_keywords(
    base_path=base_path,
)
pprint(train_random_image_paths[:2])
# Out:
# [PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n04235860/n04235860_3929.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02099849/n02099849_246.JPEG')]

# %% [markdown]
# ## Fetch `Train` Images

# %%
train_dog_image_paths = get_image_paths_by_keywords(
    base_path=base_path,
    source='train',
    preset="dogs",
    num_images=100,
    silent=False,
)
pprint(train_dog_image_paths[:5])
# Out:
# Loaded 1000 possible categories
#
# Found 1000 unique categories
#
# SEARCHING WITH KEYWORDS:
# ['affenpinscher', 'Afghan hound', 'Airedale', 'Airedale terrier', 'Alaskan malamute', 'alsatian', 'American pit bull terrier', 'American Staffordshire terrier', 'Australian terrier', 'basset', 'basset hound', 'beagle', 'Bedlington terrier', 'Bernese mountain dog', 'black-and-tan coonhound', 'Blenheim spaniel', 'bloodhound', 'bobtail', 'Border collie', 'Border terrier', 'borzoi', 'Boston bull', 'Boston terrier', 'Bouvier des Flandres', 'Bouviers des Flandres', 'Brabancon griffon', 'briard', 'Brittany spaniel', 'bull mastiff', 'cairn', 'cairn terrier', 'Cardigan Welsh corgi', 'carriage dog', 'Chesapeake Bay retriever', 'Chihuahua', 'chow chow', 'chrysanthemum dog', 'clumber', 'clumber spaniel', 'coach dog', 'cocker', 'cocker spaniel', 'collie', 'curly-coated retriever', 'dalmatian', 'Dandie Dinmont', 'Dandie Dinmont terrier', 'deerhound', 'Doberman', 'Doberman pinscher', 'elkhound', 'English cocker spaniel', 'English foxhound', 'English setter', 'English springer', 'English springer spaniel', 'Eskimo dog', 'flat-coated retriever', 'French bulldog', 'gazelle hound', 'German police dog', 'German shepherd', 'German shepherd dog', 'giant schnauzer', 'golden retriever', 'Gordon setter', 'Greater Swiss Mountain dog', 'groenendael', 'Hungarian pointer', 'husky', 'Ibizan hound', 'Ibizan Podenco', 'Irish setter', 'Irish terrier', 'Irish water spaniel', 'Irish wolfhound', 'Italian greyhound', 'Japanese spaniel', 'keeshond', 'kelpie', 'Kerry blue terrier', 'komondor', 'kuvasz', 'Labrador retriever', 'Lakeland terrier', 'Leonberg', 'malamute', 'malemute', 'malinois', 'Maltese', 'Maltese dog', 'Maltese terrier', 'miniature pinscher', 'miniature poodle', 'miniature schnauzer', 'monkey dog', 'monkey pinscher', 'Newfoundland dog', 'Norfolk terrier', 'Norwegian elkhound', 'Norwich terrier', 'Old English sheepdog', 'otter hound', 'otterhound', 'papillon', 'Peke', 'Pekinese', 'Pekingese', 'Pembroke', 'Pembroke Welsh corgi', 'pit bull terrier', 'Pomeranian', 'pug', 'pug-dog', 'red setter', 'Rhodesian ridgeback', 'Rottweiler', 'Russian wolfhound', 'Saluki', 'Samoyed', 'Samoyede', 'schipperke', 'Scotch terrier', 'Scottish deerhound', 'Scottish terrier', 'Scottie', 'Sealyham', 'Sealyham terrier', 'Shetland sheep dog', 'Shetland sheepdog', 'Shih-Tzu', 'Siberian husky', 'silky terrier', 'sleuthhound', 'soft-coated wheaten terrier', 'Staffordshire bull terrier', 'Staffordshire bullterrier', 'Staffordshire terrier', 'standard poodle', 'standard schnauzer', 'Sussex spaniel', 'Sydney silky', 'Tibetan mastiff', 'Tibetan terrier', 'toy poodle', 'toy terrier', 'vizsla', 'Walker foxhound', 'Walker hound', 'Weimaraner', 'Welsh springer spaniel', 'West Highland white terrier', 'whippet', 'wire-haired fox terrier', 'Yorkshire terrier']
#
# n02085620: Chihuahua (1300 images)
# n02085782: Japanese spaniel (772 images)
# n02085936: Maltese dog, Maltese terrier, Maltese (1300 images)
# n02104029: kuvasz (1300 images)
# n02104365: schipperke (1300 images)
# n02105056: groenendael (1300 images)
# n02105162: malinois (1300 images)
# n02105251: briard (1300 images)
# n02105412: kelpie (1300 images)
# n02105505: komondor (1300 images)
# n02105641: Old English sheepdog, bobtail (1300 images)
# n02105855: Shetland sheepdog, Shetland sheep dog, Shetland (1300 images)
# n02106030: collie (1300 images)
# n02106166: Border collie (1300 images)
# n02106382: Bouvier des Flandres, Bouviers des Flandres (1300 images)
# n02106550: Rottweiler (1300 images)
# n02106662: German shepherd, German shepherd dog, German police dog, alsatian (1300 images)
# n02107142: Doberman, Doberman pinscher (1300 images)
# n02107312: miniature pinscher (1300 images)
# n02107574: Greater Swiss Mountain dog (1300 images)
# n02107683: Bernese mountain dog (1300 images)
# n02108422: bull mastiff (1300 images)
# n02108551: Tibetan mastiff (1300 images)
# n02108915: French bulldog (1300 images)
# n02109961: Eskimo dog, husky (1300 images)
# n02110063: malamute, malemute, Alaskan malamute (1300 images)
# n02110185: Siberian husky (1300 images)
# n02110341: dalmatian, coach dog, carriage dog (1300 images)
# n02110627: affenpinscher, monkey pinscher, monkey dog (954 images)
# n02110958: pug, pug-dog (1300 images)
# n02111129: Leonberg (1300 images)
# n02111277: Newfoundland, Newfoundland dog (1300 images)
# n02111889: Samoyed, Samoyede (1300 images)
# n02112018: Pomeranian (1300 images)
# n02112137: chow, chow chow (1300 images)
# n02112350: keeshond (1300 images)
# n02112706: Brabancon griffon (1070 images)
# n02113023: Pembroke, Pembroke Welsh corgi (1300 images)
# n02113186: Cardigan, Cardigan Welsh corgi (1300 images)
# n02113624: toy poodle (1300 images)
# n02113712: miniature poodle (1300 images)
# n02113799: standard poodle (1300 images)
#
# ================================================================================
# Total matching categories: 106
# ================================================================================
#
# Total matching images available: 132992
#
# Selected 100 images
# Verified 100/100 files exist on disk
#
# [PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02106166/n02106166_12038.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02099712/n02099712_1556.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02110627/n02110627_2327.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02104365/n02104365_6489.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/train/n02087394/n02087394_639.JPEG')]

# %%
train_dog_random_index = random.randrange(len(train_dog_image_paths))
display(Image(filename=train_dog_image_paths[train_dog_random_index]))

# %% [markdown]
# ## Fetch `Val` Images

# %%
val_bird_image_paths = get_image_paths_by_keywords(
    base_path=base_path,
    source='val',
    keywords=["American eagle"],
    num_images=100,
)
pprint(val_bird_image_paths[:5])
# Out:
# [PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/val/ILSVRC2012_val_00000128.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/val/ILSVRC2012_val_00044921.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/val/ILSVRC2012_val_00039605.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/val/ILSVRC2012_val_00027079.JPEG'),
#  PosixPath('/Users/mrt/Documents/MrT/code/computer-vision/image-bank/ImageNet-Subset/ILSVRC/Data/CLS-LOC/val/ILSVRC2012_val_00027570.JPEG')]

# %%
val_bird_random_index = random.randrange(len(val_bird_image_paths))
display(Image(filename=val_bird_image_paths[val_bird_random_index]))
